# %%
import os
import numpy as np
from collections import Counter
from sklearn.naive_bayes import MultinomialNB, GaussianNB, BernoulliNB
from sklearn.svm import SVC, NuSVC, LinearSVC
from sklearn.metrics import confusion_matrix

# %%
### Creating word dictionary
def make_Dictionary(train_dir):
    emails = [os.path.join(train_dir,f) for f in os.listdir(train_dir)]    
    all_words = []       
    for mail in emails:    
        with open(mail) as m:
            for i,line in enumerate(m):
                if i == 2:  #Body of email is only 3rd line of text file
                    words = line.split()
                    all_words += words
    
    dictionary = Counter(all_words)
    # Paste code for non-word removal here(code snippet is given below) 
    return dictionary

### Feature extraction process
def extract_features(mail_dir): 
    files = [os.path.join(mail_dir,fi) for fi in os.listdir(mail_dir)]
    features_matrix = np.zeros((len(files),3000))
    docID = 0;
    for fil in files:
        with open(fil) as fi:
            for i,line in enumerate(fi):
                if i == 2:
                    words = line.split()
                    for word in words:
                        wordID = 0
                        for i,d in enumerate(dictionary):
                            if d[0] == word:
                                wordID = i
                                features_matrix[docID,wordID] = words.count(word)
            docID = docID + 1     
    return features_matrix

# %%
# Create a dictionary of words with its frequency

train_dir = 'train-mails'
dictionary = make_Dictionary(train_dir)

list_to_remove = dictionary.keys()
for item in list(dictionary):
    if item.isalpha() == False:            #isalpha
        del dictionary[item]
    elif len(item) == 1:                   #length==1
        del dictionary[item]
dictionary = dictionary.most_common(3000)  #most_common
print (dictionary[:5])

# Prepare feature vectors per training mail and its labels

train_labels = np.zeros(702)
train_labels[351:701] = 1
train_matrix = extract_features(train_dir)

print (train_matrix.shape)
# Out:
# [('order', 1414), ('address', 1293), ('report', 1216), ('mail', 1127), ('send', 1079)]
# (702, 3000)

# %%
# Training SVM and Naive bayes classifier

model1 = MultinomialNB()
model2 = LinearSVC()
model1.fit(train_matrix, train_labels)
model2.fit(train_matrix, train_labels)

# Test the unseen mails for Spam
test_dir = 'test-mails'
test_matrix = extract_features(test_dir)
test_labels = np.zeros(260)
test_labels[130:260] = 1

result1 = model1.predict(test_matrix)
result2 = model2.predict(test_matrix)
print (confusion_matrix(test_labels, result1))
print (confusion_matrix(test_labels, result2))
# Out:
# [[129   1]
#  [  9 121]]
# [[126   4]
#  [  6 124]]

# %% [markdown]
# > Input的意義是否不同?????

# %% [markdown]
# ### Finding Important Words in Text Using TF-IDF

# %%
import math
from textblob import TextBlob as tb

def tf(word, blob):
    return blob.words.count(word) / len(blob.words)

def n_containing(word, bloblist):
    return sum(1 for blob in bloblist if word in blob)

def idf(word, bloblist):
    return math.log(len(bloblist) / (1 + n_containing(word, bloblist)))

def tfidf(word, blob, bloblist):
    return tf(word, blob) * idf(word, bloblist)

# %%
document1 = tb("""Python is a 2000 made-for-TV horror movie directed by Richard
Clabaugh. The film features several cult favorite actors, including William
Zabka of The Karate Kid fame, Wil Wheaton, Casper Van Dien, Jenny McCarthy,
Keith Coogan, Robert Englund (best known for his role as Freddy Krueger in the
A Nightmare on Elm Street series of films), Dana Barron, David Bowe, and Sean
Whalen. The film concerns a genetically engineered snake, a python, that
escapes and unleashes itself on a small town. It includes the classic final
girl scenario evident in films like Friday the 13th. It was filmed in Los Angeles,
 California and Malibu, California. Python was followed by two sequels: Python
 II (2002) and Boa vs. Python (2004), both also made-for-TV films.""")

document2 = tb("""Python, from the Greek word (πύθων/πύθωνας), is a genus of
nonvenomous pythons[2] found in Africa and Asia. Currently, 7 species are
recognised.[2] A member of this genus, P. reticulatus, is among the longest
snakes known.""")

document3 = tb("""The Colt Python is a .357 Magnum caliber revolver formerly
manufactured by Colt's Manufacturing Company of Hartford, Connecticut.
It is sometimes referred to as a "Combat Magnum".[1] It was first introduced
in 1955, the same year as Smith &amp; Wesson's M29 .44 Magnum. The now discontinued
Colt Python targeted the premium revolver market segment. Some firearm
collectors and writers such as Jeff Cooper, Ian V. Hogg, Chuck Hawks, Leroy
Thompson, Renee Smeets and Martin Dougherty have described the Python as the
finest production revolver ever made.""")

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\stat_pc\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
bloblist = [document1, document2, document3]
for i, blob in enumerate(bloblist):
    print("Top words in document {}".format(i + 1))
    scores = {word: tfidf(word, blob, bloblist) for word in blob.words}
    sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    for word, score in sorted_words[:3]:
        print("Word: {}, TF-IDF: {}".format(word, round(score, 5)))
# Out:
# Top words in document 1
# Word: films, TF-IDF: 0.00997
# Word: made-for-TV, TF-IDF: 0.00665
# Word: film, TF-IDF: 0.00665
# Top words in document 2
# Word: genus, TF-IDF: 0.02192
# Word: from, TF-IDF: 0.01096
# Word: Greek, TF-IDF: 0.01096
# Top words in document 3
# Word: Colt, TF-IDF: 0.01367
# Word: Magnum, TF-IDF: 0.01367
# Word: revolver, TF-IDF: 0.01367

# %%
emails = [os.path.join(test_dir,f) for f in os.listdir(test_dir)]
bloblist = []
for mail in emails:    
    with open(mail) as m:
        for i,line in enumerate(m):
            if i == 2:  #Body of email is only 3rd line of text file
                line = tb(line)
                bloblist.append(line)

# %%
for i, blob in enumerate(bloblist):
    print("Top words in document {}".format(i + 1))
    scores = {word: tfidf(word, blob, bloblist) for word in blob.words}
    sorted_words = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    for word, score in sorted_words[:3]:
        print("Word: {}, TF-IDF: {}".format(word, round(score, 5)))
# Out:
# Top words in document 1
# Word: speech, TF-IDF: 0.06997
# Word: physiological, TF-IDF: 0.055
# Word: gruyter, TF-IDF: 0.03801
# Top words in document 2
# Word: predication, TF-IDF: 0.16285
# Word: secondary, TF-IDF: 0.12188
# Word: gruyter, TF-IDF: 0.0982
# Top words in document 3
# Word: english, TF-IDF: 0.09043
# Word: gruyter, TF-IDF: 0.06499
# Word: preterite, TF-IDF: 0.06467
# Top words in document 4
# Word: 818-677, TF-IDF: 0.12588
# Word: csun, TF-IDF: 0.12588
# Word: northridge, TF-IDF: 0.08392
# Top words in document 5
# Word: yiddish, TF-IDF: 0.15565
# Word: nanterre, TF-IDF: 0.06918
# Word: juin, TF-IDF: 0.0566
# Top words in document 6
# Word: candidate, TF-IDF: 0.04947
# Word: hiroshima, TF-IDF: 0.04947
# Word: spanish, TF-IDF: 0.04809
# Top words in document 7
# Word: notice, TF-IDF: 0.14624
# Word: board, TF-IDF: 0.08364
# Word: linguistlist, TF-IDF: 0.07275
# Top words in document 8
# Word: benjamin, TF-IDF: 0.10275
# Word: labov, TF-IDF: 0.05754
# Word: volume, TF-IDF: 0.05368
# Top words in document 9
# Word: resijb, TF-IDF: 0.20281
# Word: puctuation, TF-IDF: 0.20281
# Word: nspeech, TF-IDF: 0.18592
# Top words in document 10
# Word: netherland, TF-IDF: 0.08486
# Word: bcn, TF-IDF: 0.07387
# Word: groningen, TF-IDF: 0.05997
# Top words in document 11
# Word: ohayosenseus, TF-IDF: 0.18721
# Word: hayo, TF-IDF: 0.12481
# Word: senseus, TF-IDF: 0.12481
# Top words in document 12
# Word: sector, TF-IDF: 0.0854
# Word: cuny, TF-IDF: 0.07323
# Word: private, TF-IDF: 0.05716
# Top words in document 13
# Word: load, TF-IDF: 0.11152
# Word: tripod, TF-IDF: 0.10582
# Word: maekus, TF-IDF: 0.10582
# Top words in document 14
# Word: frequency, TF-IDF: 0.05613
# Word: spanish, TF-IDF: 0.04419
# Word: palabra, TF-IDF: 0.04165
# Top words in document 15
# Word: kubo, TF-IDF: 0.09234
# Word: japanese, TF-IDF: 0.04871
# Word: harukanaru, TF-IDF: 0.03957
# Top words in document 16
# Word: galore, TF-IDF: 0.40564
# Word: belatedly, TF-IDF: 0.11063
# Word: obligatorily, TF-IDF: 0.11063
# Top words in document 17
# Word: plural, TF-IDF: 0.21581
# Word: 510, TF-IDF: 0.1332
# Word: berkeley, TF-IDF: 0.1004
# Top words in document 18
# Word: punctuation, TF-IDF: 0.23854
# Word: caroline, TF-IDF: 0.21537
# Word: punct-l, TF-IDF: 0.13907
# Top words in document 19
# Word: teach, TF-IDF: 0.09079
# Word: preposition, TF-IDF: 0.069
# Word: infinitive, TF-IDF: 0.0611
# Top words in document 20
# Word: turkic, TF-IDF: 0.33569
# Word: mongolic, TF-IDF: 0.33569
# Word: binary, TF-IDF: 0.2725
# Top words in document 21
# Word: workshop, TF-IDF: 0.05176
# Word: september, TF-IDF: 0.05085
# Word: technique, TF-IDF: 0.04851
# Top words in document 22
# Word: die, TF-IDF: 0.03373
# Word: kaffeepause, TF-IDF: 0.03181
# Word: 45, TF-IDF: 0.03058
# Top words in document 23
# Word: pound, TF-IDF: 0.0546
# Word: sterl, TF-IDF: 0.04346
# Word: ss12, TF-IDF: 0.04214
# Top words in document 24
# Word: pronunciation, TF-IDF: 0.13345
# Word: pronounce, TF-IDF: 0.05459
# Word: analogy, TF-IDF: 0.03901
# Top words in document 25
# Word: iii, TF-IDF: 0.46146
# Word: termistus, TF-IDF: 0.14316
# Word: campenhoudt, TF-IDF: 0.10737
# Top words in document 26
# Word: conceptual, TF-IDF: 0.1064
# Word: graph, TF-IDF: 0.06514
# Word: knowledge, TF-IDF: 0.03207
# Top words in document 27
# Word: mt, TF-IDF: 0.06925
# Word: 619, TF-IDF: 0.04225
# Word: exhibit, TF-IDF: 0.03639
# Top words in document 28
# Word: resolution, TF-IDF: 0.07013
# Word: mitkov, TF-IDF: 0.06881
# Word: anaphora, TF-IDF: 0.05958
# Top words in document 29
# Word: workshop, TF-IDF: 0.04854
# Word: technique, TF-IDF: 0.0455
# Word: quantitative, TF-IDF: 0.0446
# Top words in document 30
# Word: endanger, TF-IDF: 0.07499
# Word: pound, TF-IDF: 0.06595
# Word: york, TF-IDF: 0.05435
# Top words in document 31
# Word: leed, TF-IDF: 0.17498
# Word: english, TF-IDF: 0.0734
# Word: variation, TF-IDF: 0.06388
# Top words in document 32
# Word: portugal, TF-IDF: 0.11933
# Word: coimbra, TF-IDF: 0.09622
# Word: epia, TF-IDF: 0.0849
# Top words in document 33
# Word: kassel, TF-IDF: 0.22817
# Word: 32nd, TF-IDF: 0.15211
# Word: uni-kassel, TF-IDF: 0.15211
# Top words in document 34
# Word: movement, TF-IDF: 0.05509
# Word: extraposition, TF-IDF: 0.0512
# Word: kayne, TF-IDF: 0.04295
# Top words in document 35
# Word: movement, TF-IDF: 0.04104
# Word: hoekstra, TF-IDF: 0.04088
# Word: kayne, TF-IDF: 0.03792
# Top words in document 36
# Word: worthington, TF-IDF: 0.1298
# Word: tstewart, TF-IDF: 0.1298
# Word: ohio-state, TF-IDF: 0.1298
# Top words in document 37
# Word: phonology, TF-IDF: 0.13953
# Word: hilp, TF-IDF: 0.0649
# Word: iconicity, TF-IDF: 0.0649
# Top words in document 38
# Word: aviv, TF-IDF: 0.06843
# Word: pragma99, TF-IDF: 0.05985
# Word: panel, TF-IDF: 0.05846
# Top words in document 39
# Word: uiuc, TF-IDF: 0.19878
# Word: pragmatic, TF-IDF: 0.14647
# Word: lanaguage, TF-IDF: 0.11589
# Top words in document 40
# Word: proposal, TF-IDF: 0.05441
# Word: esol, TF-IDF: 0.05327
# Word: teacher, TF-IDF: 0.02955
# Top words in document 41
# Word: leuven, TF-IDF: 0.08798
# Word: langue, TF-IDF: 0.07432
# Word: colloquium, TF-IDF: 0.06678
# Top words in document 42
# Word: luton, TF-IDF: 0.07388
# Word: stlg20, TF-IDF: 0.05384
# Word: relevance, TF-IDF: 0.05046
# Top words in document 43
# Word: gruyter, TF-IDF: 0.09721
# Word: mouton, TF-IDF: 0.07533
# Word: berlin, TF-IDF: 0.05334
# Top words in document 44
# Word: gruyter, TF-IDF: 0.12305
# Word: mouton, TF-IDF: 0.1192
# Word: degruyter, TF-IDF: 0.08491
# Top words in document 45
# Word: gender, TF-IDF: 0.06047
# Word: gruyter, TF-IDF: 0.05008
# Word: woman, TF-IDF: 0.04902
# Top words in document 46
# Word: gruyter, TF-IDF: 0.17473
# Word: mouton, TF-IDF: 0.12694
# Word: degruyter, TF-IDF: 0.09042
# Top words in document 47
# Word: incorporation, TF-IDF: 0.08836
# Word: stanford, TF-IDF: 0.0659
# Word: semantic, TF-IDF: 0.04913
# Top words in document 48
# Word: learnable, TF-IDF: 0.07158
# Word: 1-57586, TF-IDF: 0.04946
# Word: categorial, TF-IDF: 0.04358
# Top words in document 49
# Word: autre, TF-IDF: 0.25845
# Word: langue, TF-IDF: 0.20012
# Word: uwo, TF-IDF: 0.09872
# Top words in document 50
# Word: semantics, TF-IDF: 0.10912
# Word: stanford, TF-IDF: 0.07794
# Word: propositional, TF-IDF: 0.0532
# Top words in document 51
# Word: stanford, TF-IDF: 0.08239
# Word: 1-57586, TF-IDF: 0.04857
# Word: database, TF-IDF: 0.0463
# Top words in document 52
# Word: sound-symbolic, TF-IDF: 0.19088
# Word: stanford, TF-IDF: 0.13983
# Word: expression, TF-IDF: 0.1319
# Top words in document 53
# Word: morphology, TF-IDF: 0.12089
# Word: stanford, TF-IDF: 0.09837
# Word: compound, TF-IDF: 0.05758
# Top words in document 54
# Word: bantu, TF-IDF: 0.17746
# Word: tone, TF-IDF: 0.09066
# Word: stanford, TF-IDF: 0.07429
# Top words in document 55
# Word: stanford, TF-IDF: 0.11788
# Word: case, TF-IDF: 0.1041
# Word: constructive, TF-IDF: 0.08046
# Top words in document 56
# Word: translation, TF-IDF: 0.08022
# Word: mitkov, TF-IDF: 0.07016
# Word: anaphora, TF-IDF: 0.06835
# Top words in document 57
# Word: romance, TF-IDF: 0.11824
# Word: mla, TF-IDF: 0.0834
# Word: comparative, TF-IDF: 0.07998
# Top words in document 58
# Word: computer, TF-IDF: 0.08623
# Word: assist, TF-IDF: 0.08092
# Word: journal, TF-IDF: 0.07928
# Top words in document 59
# Word: soas, TF-IDF: 0.14603
# Word: afro, TF-IDF: 0.09735
# Word: asiatic, TF-IDF: 0.08924
# Top words in document 60
# Word: arabic, TF-IDF: 0.19259
# Word: university, TF-IDF: 0.04142
# Word: 45, TF-IDF: 0.04074
# Top words in document 61
# Word: zock, TF-IDF: 0.08882
# Word: limsi, TF-IDF: 0.04326
# Word: submission, TF-IDF: 0.04161
# Top words in document 62
# Word: coreference, TF-IDF: 0.08703
# Word: rule, TF-IDF: 0.03205
# Word: microtheory, TF-IDF: 0.03125
# Top words in document 63
# Word: acquisition, TF-IDF: 0.10961
# Word: crosslinguistic, TF-IDF: 0.10084
# Word: slobin, TF-IDF: 0.0825
# Top words in document 64
# Word: esslli-98, TF-IDF: 0.09397
# Word: tibor, TF-IDF: 0.05638
# Word: workshop, TF-IDF: 0.05631
# Top words in document 65
# Word: analogy, TF-IDF: 0.07336
# Word: usa, TF-IDF: 0.03373
# Word: edu, TF-IDF: 0.02703
# Top words in document 66
# Word: mks, TF-IDF: 0.04475
# Word: khmer, TF-IDF: 0.04131
# Word: taus, TF-IDF: 0.03787
# Top words in document 67
# Word: alberta, TF-IDF: 0.12527
# Word: canada, TF-IDF: 0.07544
# Word: libben, TF-IDF: 0.07158
# Top words in document 68
# Word: partitive, TF-IDF: 0.13828
# Word: quantification, TF-IDF: 0.05071
# Word: zwart, TF-IDF: 0.05071
# Top words in document 69
# Word: kdd, TF-IDF: 0.0776
# Word: discovery, TF-IDF: 0.06555
# Word: datum, TF-IDF: 0.05957
# Top words in document 70
# Word: slavic, TF-IDF: 0.10568
# Word: indiana, TF-IDF: 0.0661
# Word: 1-812, TF-IDF: 0.06161
# Top words in document 71
# Word: clite, TF-IDF: 0.08392
# Word: szege, TF-IDF: 0.08392
# Word: hungary, TF-IDF: 0.08392
# Top words in document 72
# Word: fluency, TF-IDF: 0.09184
# Word: session, TF-IDF: 0.08584
# Word: berkeley, TF-IDF: 0.06346
# Top words in document 73
# Word: discourse, TF-IDF: 0.11803
# Word: teun, TF-IDF: 0.10065
# Word: specialization, TF-IDF: 0.0671
# Top words in document 74
# Word: esca, TF-IDF: 0.081
# Word: lpl, TF-IDF: 0.07761
# Word: spontaneous, TF-IDF: 0.06653
# Top words in document 75
# Word: modal, TF-IDF: 0.1913
# Word: modality, TF-IDF: 0.07889
# Word: epistemic, TF-IDF: 0.0676
# Top words in document 76
# Word: discourse, TF-IDF: 0.11803
# Word: teun, TF-IDF: 0.10065
# Word: specialization, TF-IDF: 0.0671
# Top words in document 77
# Word: evaluation, TF-IDF: 0.06371
# Word: scheme, TF-IDF: 0.04153
# Word: carroll, TF-IDF: 0.03928
# Top words in document 78
# Word: sfr, TF-IDF: 0.12019
# Word: minority, TF-IDF: 0.08305
# Word: congress, TF-IDF: 0.08143
# Top words in document 79
# Word: nlp, TF-IDF: 0.07448
# Word: verga, TF-IDF: 0.05085
# Word: adaptive, TF-IDF: 0.04503
# Top words in document 80
# Word: node, TF-IDF: 0.09252
# Word: dats, TF-IDF: 0.07814
# Word: meulen, TF-IDF: 0.06186
# Top words in document 81
# Word: pm, TF-IDF: 0.05793
# Word: boardroom, TF-IDF: 0.05416
# Word: university, TF-IDF: 0.04071
# Top words in document 82
# Word: university, TF-IDF: 0.05148
# Word: phonetic, TF-IDF: 0.04697
# Word: 10, TF-IDF: 0.04599
# Top words in document 83
# Word: jussieu, TF-IDF: 0.06368
# Word: linguistique, TF-IDF: 0.06027
# Word: cabredo, TF-IDF: 0.04125
# Top words in document 84
# Word: japan, TF-IDF: 0.0982
# Word: yamaguchus, TF-IDF: 0.0605
# Word: chinese, TF-IDF: 0.05749
# Top words in document 85
# Word: 471, TF-IDF: 0.05939
# Word: whole, TF-IDF: 0.03965
# Word: polus, TF-IDF: 0.03786
# Top words in document 86
# Word: greece, TF-IDF: 0.09455
# Word: crete, TF-IDF: 0.06829
# Word: library, TF-IDF: 0.06265
# Top words in document 87
# Word: bilingualism, TF-IDF: 0.0988
# Word: newcastle, TF-IDF: 0.0576
# Word: tyne, TF-IDF: 0.0576
# Top words in document 88
# Word: leuven, TF-IDF: 0.15126
# Word: metaphor, TF-IDF: 0.06289
# Word: cognitive, TF-IDF: 0.0359
# Top words in document 89
# Word: console, TF-IDF: 0.08972
# Word: sole, TF-IDF: 0.08684
# Word: uib, TF-IDF: 0.06729
# Top words in document 90
# Word: library, TF-IDF: 0.08091
# Word: digital, TF-IDF: 0.06428
# Word: greece, TF-IDF: 0.05699
# Top words in document 91
# Word: charniak, TF-IDF: 0.05001
# Word: eugene, TF-IDF: 0.04584
# Word: brown, TF-IDF: 0.04289
# Top words in document 92
# Word: peseta, TF-IDF: 0.05702
# Word: evaluation, TF-IDF: 0.0544
# Word: lrec, TF-IDF: 0.04283
# Top words in document 93
# Word: oregon, TF-IDF: 0.34768
# Word: hokan, TF-IDF: 0.23179
# Word: penutian, TF-IDF: 0.23179
# Top words in document 94
# Word: franklin, TF-IDF: 0.04828
# Word: clipper, TF-IDF: 0.03965
# Word: hibb, TF-IDF: 0.03965
# Top words in document 95
# Word: emnlp3, TF-IDF: 0.04942
# Word: registration, TF-IDF: 0.04173
# Word: vassar, TF-IDF: 0.03775
# Top words in document 96
# Word: manchester, TF-IDF: 0.15435
# Word: mirail, TF-IDF: 0.11408
# Word: toulouse, TF-IDF: 0.09784
# Top words in document 97
# Word: prolamat, TF-IDF: 0.17863
# Word: agility, TF-IDF: 0.08931
# Word: telecom, TF-IDF: 0.06388
# Top words in document 98
# Word: minority, TF-IDF: 0.04657
# Word: switzerland, TF-IDF: 0.03707
# Word: congress, TF-IDF: 0.03612
# Top words in document 99
# Word: yale, TF-IDF: 0.16886
# Word: clitic, TF-IDF: 0.13509
# Word: phenomena, TF-IDF: 0.07136
# Top words in document 100
# Word: moncton, TF-IDF: 0.04881
# Word: canada, TF-IDF: 0.0441
# Word: nlp, TF-IDF: 0.03525
# Top words in document 101
# Word: upenn, TF-IDF: 0.04627
# Word: july, TF-IDF: 0.0453
# Word: grammar, TF-IDF: 0.03813
# Top words in document 102
# Word: italian, TF-IDF: 0.08301
# Word: vowel, TF-IDF: 0.06652
# Word: phonologicum, TF-IDF: 0.06201
# Top words in document 103
# Word: summary, TF-IDF: 0.04726
# Word: icslp98, TF-IDF: 0.04332
# Word: speech, TF-IDF: 0.04259
# Top words in document 104
# Word: peseta, TF-IDF: 0.04511
# Word: spain, TF-IDF: 0.04494
# Word: resource, TF-IDF: 0.0342
# Top words in document 105
# Word: course, TF-IDF: 0.10274
# Word: dekker, TF-IDF: 0.09045
# Word: beaver, TF-IDF: 0.06578
# Top words in document 106
# Word: altmann, TF-IDF: 0.07338
# Word: gerry, TF-IDF: 0.04892
# Word: 1904, TF-IDF: 0.04892
# Top words in document 107
# Word: aplin, TF-IDF: 0.15211
# Word: awareness, TF-IDF: 0.13045
# Word: leicester, TF-IDF: 0.09296
# Top words in document 108
# Word: evaluation, TF-IDF: 0.065
# Word: scheme, TF-IDF: 0.04237
# Word: carroll, TF-IDF: 0.04007
# Top words in document 109
# Word: velardus, TF-IDF: 0.05645
# Word: roma, TF-IDF: 0.04886
# Word: paolum, TF-IDF: 0.04487
# Top words in document 110
# Word: iceland, TF-IDF: 0.08697
# Word: 354, TF-IDF: 0.08697
# Word: rhus, TF-IDF: 0.08451
# Top words in document 111
# Word: lexical, TF-IDF: 0.08041
# Word: scuolum, TF-IDF: 0.06939
# Word: normale, TF-IDF: 0.06939
# Top words in document 112
# Word: terminology, TF-IDF: 0.06885
# Word: france, TF-IDF: 0.05496
# Word: montreal, TF-IDF: 0.04805
# Top words in document 113
# Word: document, TF-IDF: 0.15061
# Word: instructive, TF-IDF: 0.09271
# Word: persuasive, TF-IDF: 0.09271
# Top words in document 114
# Word: queensland, TF-IDF: 0.10688
# Word: als-98, TF-IDF: 0.08744
# Word: cltr, TF-IDF: 0.08744
# Top words in document 115
# Word: scil, TF-IDF: 0.10425
# Word: nwu, TF-IDF: 0.06255
# Word: northwestern, TF-IDF: 0.05852
# Top words in document 116
# Word: clemson, TF-IDF: 0.0745
# Word: stream, TF-IDF: 0.05148
# Word: cognitive, TF-IDF: 0.04863
# Top words in document 117
# Word: grup, TF-IDF: 0.17384
# Word: grlmc, TF-IDF: 0.17384
# Word: wml, TF-IDF: 0.15936
# Top words in document 118
# Word: intercultural, TF-IDF: 0.17781
# Word: 246teborg, TF-IDF: 0.0889
# Word: communication, TF-IDF: 0.07011
# Top words in document 119
# Word: abraham, TF-IDF: 0.06729
# Word: sov, TF-IDF: 0.06729
# Word: groningen, TF-IDF: 0.05463
# Top words in document 120
# Word: perception, TF-IDF: 0.12857
# Word: perceive, TF-IDF: 0.10181
# Word: book, TF-IDF: 0.09381
# Top words in document 121
# Word: acquisition, TF-IDF: 0.0703
# Word: chicago, TF-IDF: 0.05462
# Word: uchicago, TF-IDF: 0.05291
# Top words in document 122
# Word: resource, TF-IDF: 0.12216
# Word: access, TF-IDF: 0.03638
# Word: programmatic, TF-IDF: 0.03632
# Top words in document 123
# Word: dgs, TF-IDF: 0.09452
# Word: montreal, TF-IDF: 0.06531
# Word: umontreal, TF-IDF: 0.05115
# Top words in document 124
# Word: syllable, TF-IDF: 0.1291
# Word: sprachwissenschaft, TF-IDF: 0.07056
# Word: cruz, TF-IDF: 0.05795
# Top words in document 125
# Word: syntaxis, TF-IDF: 0.15502
# Word: huelva, TF-IDF: 0.12401
# Word: journal, TF-IDF: 0.09998
# Top words in document 126
# Word: inversion, TF-IDF: 0.13343
# Word: amsterdam, TF-IDF: 0.05336
# Word: pollock, TF-IDF: 0.04445
# Top words in document 127
# Word: evaluation, TF-IDF: 0.0586
# Word: workshop, TF-IDF: 0.05143
# Word: else, TF-IDF: 0.04645
# Top words in document 128
# Word: lfg98, TF-IDF: 0.12207
# Word: usyd, TF-IDF: 0.09155
# Word: sultry, TF-IDF: 0.06103
# Top words in document 129
# Word: icslp98, TF-IDF: 0.046
# Word: speech, TF-IDF: 0.04256
# Word: submission, TF-IDF: 0.04198
# Top words in document 130
# Word: professore, TF-IDF: 0.11534
# Word: unicamp, TF-IDF: 0.08459
# Word: campina, TF-IDF: 0.06921
# Top words in document 131
# Word: timer, TF-IDF: 0.2698
# Word: aol, TF-IDF: 0.24103
# Word: antus, TF-IDF: 0.15848
# Top words in document 132
# Word: 600, TF-IDF: 0.07096
# Word: trouble, TF-IDF: 0.06052
# Word: site, TF-IDF: 0.05892
# Top words in document 133
# Word: 600, TF-IDF: 0.07096
# Word: trouble, TF-IDF: 0.06052
# Word: site, TF-IDF: 0.05892
# Top words in document 134
# Word: 600, TF-IDF: 0.07096
# Word: trouble, TF-IDF: 0.06052
# Word: site, TF-IDF: 0.05892
# Top words in document 135
# Word: y2k, TF-IDF: 0.15959
# Word: popmail, TF-IDF: 0.15959
# Word: period, TF-IDF: 0.09141
# Top words in document 136
# Word: capitalfm, TF-IDF: 0.05589
# Word: week, TF-IDF: 0.03856
# Word: pop, TF-IDF: 0.03249
# Top words in document 137
# Word: adlu, TF-IDF: 0.12676
# Word: bestockpix, TF-IDF: 0.12676
# Word: investor, TF-IDF: 0.08697
# Top words in document 138
# Word: wspn, TF-IDF: 0.39735
# Word: sport, TF-IDF: 0.12554
# Word: cavalcade, TF-IDF: 0.09934
# Top words in document 139
# Word: listbot, TF-IDF: 0.25068
# Word: kiddin, TF-IDF: 0.16407
# Word: subscription, TF-IDF: 0.07823
# Top words in document 140
# Word: merchant, TF-IDF: 0.07863
# Word: index2, TF-IDF: 0.07265
# Word: 668920828, TF-IDF: 0.0666
# Top words in document 141
# Word: capitalfm, TF-IDF: 0.0633
# Word: album, TF-IDF: 0.0632
# Word: lyric, TF-IDF: 0.04407
# Top words in document 142
# Word: webdomain, TF-IDF: 0.2296
# Word: domain, TF-IDF: 0.16309
# Word: easy-to, TF-IDF: 0.09184
# Top words in document 143
# Word: 38, TF-IDF: 0.25976
# Word: xenical, TF-IDF: 0.23179
# Word: drug, TF-IDF: 0.23179
# Top words in document 144
# Word: descrambler, TF-IDF: 0.15475
# Word: cable, TF-IDF: 0.10893
# Word: radar, TF-IDF: 0.05627
# Top words in document 145
# Word: prices, TF-IDF: 0.06954
# Word: 228-2095, TF-IDF: 0.06954
# Word: 822223281, TF-IDF: 0.06954
# Top words in document 146
# Word: capitalfm, TF-IDF: 0.06
# Word: festival, TF-IDF: 0.05354
# Word: album, TF-IDF: 0.04194
# Top words in document 147
# Word: report, TF-IDF: 0.04716
# Word: program, TF-IDF: 0.02332
# Word: business, TF-IDF: 0.02016
# Top words in document 148
# Word: microsoft, TF-IDF: 0.21951
# Word: 2000, TF-IDF: 0.17351
# Word: powerpoint, TF-IDF: 0.05795
# Top words in document 149
# Word: credit, TF-IDF: 0.14616
# Word: wipe, TF-IDF: 0.1132
# Word: re-establish, TF-IDF: 0.1132
# Top words in document 150
# Word: software, TF-IDF: 0.06422
# Word: 92t, TF-IDF: 0.0603
# Word: advertiser, TF-IDF: 0.04701
# Top words in document 151
# Word: casino, TF-IDF: 0.33868
# Word: raquel, TF-IDF: 0.13907
# Word: sportsbook, TF-IDF: 0.13907
# Top words in document 152
# Word: nek, TF-IDF: 0.20359
# Word: game, TF-IDF: 0.11937
# Word: tetri, TF-IDF: 0.11105
# Top words in document 153
# Word: reply, TF-IDF: 0.09798
# Word: wholesale, TF-IDF: 0.09494
# Word: array, TF-IDF: 0.09494
# Top words in document 154
# Word: capitalfm, TF-IDF: 0.04078
# Word: festival, TF-IDF: 0.03336
# Word: july, TF-IDF: 0.03117
# Top words in document 155
# Word: everythe, TF-IDF: 0.10817
# Word: 30-200, TF-IDF: 0.10817
# Word: wholesale, TF-IDF: 0.09916
# Top words in document 156
# Word: newsletter, TF-IDF: 0.10768
# Word: asian, TF-IDF: 0.10768
# Word: lens, TF-IDF: 0.06954
# Top words in document 157
# Word: entertainment, TF-IDF: 0.18818
# Word: scout, TF-IDF: 0.13155
# Word: 55444, TF-IDF: 0.13155
# Top words in document 158
# Word: 59179, TF-IDF: 0.1947
# Word: 18-21, TF-IDF: 0.17848
# Word: 251, TF-IDF: 0.16698
# Top words in document 159
# Word: survey, TF-IDF: 0.19579
# Word: entertainment, TF-IDF: 0.09042
# Word: participate, TF-IDF: 0.07409
# Top words in document 160
# Word: wildhotsex, TF-IDF: 0.28633
# Word: puresex1, TF-IDF: 0.28633
# Word: jillbob622, TF-IDF: 0.14316
# Top words in document 161
# Word: xq36tst, TF-IDF: 0.16225
# Word: xoom, TF-IDF: 0.14874
# Word: invitation, TF-IDF: 0.13171
# Top words in document 162
# Word: 773712909, TF-IDF: 0.08664
# Word: remove, TF-IDF: 0.07453
# Word: teen, TF-IDF: 0.05972
# Top words in document 163
# Word: 773712909, TF-IDF: 0.08664
# Word: terry, TF-IDF: 0.08106
# Word: remove, TF-IDF: 0.07453
# Top words in document 164
# Word: stop, TF-IDF: 0.21289
# Word: erotic, TF-IDF: 0.18974
# Word: oodles, TF-IDF: 0.18974
# Top words in document 165
# Word: stop, TF-IDF: 0.21289
# Word: erotic, TF-IDF: 0.18974
# Word: oodles, TF-IDF: 0.18974
# Top words in document 166
# Word: stop, TF-IDF: 0.21289
# Word: erotic, TF-IDF: 0.18974
# Word: oodles, TF-IDF: 0.18974
# Top words in document 167
# Word: fuck, TF-IDF: 0.07788
# Word: 732-942, TF-IDF: 0.07788
# Word: 7100, TF-IDF: 0.07788
# Top words in document 168
# Word: xxxnet, TF-IDF: 0.2596
# Word: cx, TF-IDF: 0.2596
# Word: 46ree, TF-IDF: 0.17848
# Top words in document 169
# Word: acmecity, TF-IDF: 0.23179
# Word: smallscreen, TF-IDF: 0.23179
# Word: 25061, TF-IDF: 0.23179
# Top words in document 170
# Word: 789946013, TF-IDF: 0.25619
# Word: jeni20, TF-IDF: 0.25619
# Word: 65857, TF-IDF: 0.25619
# Top words in document 171
# Word: babez, TF-IDF: 0.40563
# Word: 76557, TF-IDF: 0.40563
# Word: 150, TF-IDF: 0.2901
# Top words in document 172
# Word: sincity, TF-IDF: 0.13907
# Word: xxxclub, TF-IDF: 0.13907
# Word: tommy, TF-IDF: 0.13907
# Top words in document 173
# Word: 46ree, TF-IDF: 0.23485
# Word: 46or, TF-IDF: 0.20796
# Word: 833199302, TF-IDF: 0.17079
# Top words in document 174
# Word: csend, TF-IDF: 0.36056
# Word: 814493884, TF-IDF: 0.33052
# Word: straight1, TF-IDF: 0.18028
# Top words in document 175
# Word: 407-599, TF-IDF: 0.13386
# Word: 5253, TF-IDF: 0.13386
# Word: account, TF-IDF: 0.09749
# Top words in document 176
# Word: 407-599, TF-IDF: 0.0963
# Word: 5253, TF-IDF: 0.0963
# Word: adult, TF-IDF: 0.09411
# Top words in document 177
# Word: certificate, TF-IDF: 0.28005
# Word: gift, TF-IDF: 0.22077
# Word: shoppe, TF-IDF: 0.10183
# Top words in document 178
# Word: wilderhotsex, TF-IDF: 0.25619
# Word: indexe, TF-IDF: 0.23485
# Word: adults, TF-IDF: 0.20796
# Top words in document 179
# Word: company, TF-IDF: 0.03618
# Word: coupon, TF-IDF: 0.03472
# Word: market, TF-IDF: 0.0331
# Top words in document 180
# Word: financial, TF-IDF: 0.10182
# Word: extraordinary, TF-IDF: 0.0507
# Word: skills, TF-IDF: 0.0507
# Top words in document 181
# Word: report, TF-IDF: 0.04677
# Word: reports, TF-IDF: 0.03177
# Word: business, TF-IDF: 0.02336
# Top words in document 182
# Word: cd, TF-IDF: 0.0485
# Word: address, TF-IDF: 0.04045
# Word: million, TF-IDF: 0.02834
# Top words in document 183
# Word: cd, TF-IDF: 0.0485
# Word: address, TF-IDF: 0.04045
# Word: million, TF-IDF: 0.02834
# Top words in document 184
# Word: bulk, TF-IDF: 0.0248
# Word: bonus, TF-IDF: 0.02432
# Word: email, TF-IDF: 0.02365
# Top words in document 185
# Word: cd, TF-IDF: 0.04942
# Word: anywhere, TF-IDF: 0.03052
# Word: 1-412, TF-IDF: 0.02834
# Top words in document 186
# Word: imagine, TF-IDF: 0.07111
# Word: percent, TF-IDF: 0.0682
# Word: bulk, TF-IDF: 0.05803
# Top words in document 187
# Word: victorian, TF-IDF: 0.23744
# Word: fortunecity, TF-IDF: 0.23744
# Word: kingston, TF-IDF: 0.23744
# Top words in document 188
# Word: fat, TF-IDF: 0.08607
# Word: fat-loss, TF-IDF: 0.06954
# Word: surgery, TF-IDF: 0.06954
# Top words in document 189
# Word: smoke, TF-IDF: 0.15936
# Word: kick, TF-IDF: 0.1346
# Word: non-smoker, TF-IDF: 0.08692
# Top words in document 190
# Word: christmas, TF-IDF: 0.11096
# Word: capitalfm, TF-IDF: 0.07267
# Word: win, TF-IDF: 0.03311
# Top words in document 191
# Word: bankruptcy, TF-IDF: 0.34062
# Word: american, TF-IDF: 0.08845
# Word: server8, TF-IDF: 0.08392
# Top words in document 192
# Word: theman11, TF-IDF: 0.23744
# Word: angelfire, TF-IDF: 0.21766
# Word: adults, TF-IDF: 0.19274
# Top words in document 193
# Word: degree, TF-IDF: 0.25346
# Word: 602-230, TF-IDF: 0.09487
# Word: 4252, TF-IDF: 0.09487
# Top words in document 194
# Word: mind, TF-IDF: 0.12056
# Word: feeling, TF-IDF: 0.10988
# Word: figurative, TF-IDF: 0.06593
# Top words in document 195
# Word: capitalfm, TF-IDF: 0.07875
# Word: quiz, TF-IDF: 0.06388
# Word: holiday, TF-IDF: 0.0599
# Top words in document 196
# Word: barefoot, TF-IDF: 0.12643
# Word: 301, TF-IDF: 0.08736
# Word: section, TF-IDF: 0.06535
# Top words in document 197
# Word: auto, TF-IDF: 0.07277
# Word: vehicle, TF-IDF: 0.06724
# Word: downpayment, TF-IDF: 0.06668
# Top words in document 198
# Word: degree, TF-IDF: 0.07561
# Word: wallace, TF-IDF: 0.066
# Word: school, TF-IDF: 0.05217
# Top words in document 199
# Word: degree, TF-IDF: 0.25346
# Word: 602-230, TF-IDF: 0.09487
# Word: 4252, TF-IDF: 0.09487
# Top words in document 200
# Word: howard, TF-IDF: 0.04786
# Word: job, TF-IDF: 0.04528
# Word: movie, TF-IDF: 0.04421
# Top words in document 201
# Word: tap, TF-IDF: 0.1826
# Word: job, TF-IDF: 0.17829
# Word: recruitment, TF-IDF: 0.15211
# Top words in document 202
# Word: coffee, TF-IDF: 0.36928
# Word: coast, TF-IDF: 0.09676
# Word: grinder, TF-IDF: 0.09671
# Top words in document 203
# Word: degree, TF-IDF: 0.25346
# Word: 602-230, TF-IDF: 0.09487
# Word: 4252, TF-IDF: 0.09487
# Top words in document 204
# Word: 1-900, TF-IDF: 0.13521
# Word: 435-3541, TF-IDF: 0.13521
# Word: 1-888, TF-IDF: 0.07317
# Top words in document 205
# Word: degree, TF-IDF: 0.25346
# Word: 713-866, TF-IDF: 0.10141
# Word: 4087, TF-IDF: 0.0898
# Top words in document 206
# Word: judgment, TF-IDF: 0.11959
# Word: judicial, TF-IDF: 0.0657
# Word: course, TF-IDF: 0.04295
# Top words in document 207
# Word: herbal, TF-IDF: 0.11846
# Word: health, TF-IDF: 0.09597
# Word: regeneration, TF-IDF: 0.08615
# Top words in document 208
# Word: judgment, TF-IDF: 0.15081
# Word: judicial, TF-IDF: 0.12746
# Word: uncollect, TF-IDF: 0.0956
# Top words in document 209
# Word: degree, TF-IDF: 0.25346
# Word: 713-866, TF-IDF: 0.10141
# Word: 4087, TF-IDF: 0.0898
# Top words in document 210
# Word: driver, TF-IDF: 0.22261
# Word: license, TF-IDF: 0.17819
# Word: suspend, TF-IDF: 0.11759
# Top words in document 211
# Word: driver, TF-IDF: 0.22261
# Word: license, TF-IDF: 0.17819
# Word: suspend, TF-IDF: 0.11759
# Top words in document 212
# Word: album, TF-IDF: 0.0567
# Word: competition, TF-IDF: 0.04952
# Word: golden, TF-IDF: 0.04756
# Top words in document 213
# Word: pdcid, TF-IDF: 0.28633
# Word: medical, TF-IDF: 0.14176
# Word: sterile, TF-IDF: 0.09544
# Top words in document 214
# Word: judgment, TF-IDF: 0.15081
# Word: judicial, TF-IDF: 0.12746
# Word: uncollect, TF-IDF: 0.0956
# Top words in document 215
# Word: valentine, TF-IDF: 0.07158
# Word: music, TF-IDF: 0.05873
# Word: backstage, TF-IDF: 0.05249
# Top words in document 216
# Word: travel, TF-IDF: 0.12169
# Word: wordlwide, TF-IDF: 0.1132
# Word: airline, TF-IDF: 0.09708
# Top words in document 217
# Word: bobby, TF-IDF: 0.46357
# Word: immedaitly, TF-IDF: 0.23179
# Word: cousin, TF-IDF: 0.19878
# Top words in document 218
# Word: nbsp, TF-IDF: 0.291
# Word: ipcug, TF-IDF: 0.13888
# Word: tufftest, TF-IDF: 0.08598
# Top words in document 219
# Word: showtime, TF-IDF: 0.05887
# Word: brits, TF-IDF: 0.05507
# Word: grammy, TF-IDF: 0.03853
# Top words in document 220
# Word: 95you, TF-IDF: 0.06205
# Word: 20, TF-IDF: 0.05907
# Word: a0, TF-IDF: 0.05321
# Top words in document 221
# Word: gift, TF-IDF: 0.39673
# Word: somebody, TF-IDF: 0.25619
# Word: pardon, TF-IDF: 0.2197
# Top words in document 222
# Word: photomask, TF-IDF: 0.51625
# Word: adtek, TF-IDF: 0.295
# Word: adtekphotomask, TF-IDF: 0.1475
# Top words in document 223
# Word: hollander, TF-IDF: 0.50354
# Word: photography, TF-IDF: 0.16785
# Word: gino, TF-IDF: 0.08392
# Top words in document 224
# Word: favourite, TF-IDF: 0.05672
# Word: london, TF-IDF: 0.03457
# Word: pick, TF-IDF: 0.03263
# Top words in document 225
# Word: vacation, TF-IDF: 0.1448
# Word: package, TF-IDF: 0.11868
# Word: nutty2, TF-IDF: 0.10817
# Top words in document 226
# Word: strengthen, TF-IDF: 0.14316
# Word: marriage, TF-IDF: 0.12278
# Word: increase, TF-IDF: 0.10158
# Top words in document 227
# Word: manager, TF-IDF: 0.15461
# Word: bill, TF-IDF: 0.14374
# Word: monthly, TF-IDF: 0.13387
# Top words in document 228
# Word: kingscasino, TF-IDF: 0.20281
# Word: antigua, TF-IDF: 0.18592
# Word: casino, TF-IDF: 0.16464
# Top words in document 229
# Word: robber9, TF-IDF: 0.15452
# Word: 361, TF-IDF: 0.14165
# Word: ak2, TF-IDF: 0.14165
# Top words in document 230
# Word: whitney, TF-IDF: 0.04967
# Word: pick, TF-IDF: 0.04768
# Word: win, TF-IDF: 0.04359
# Top words in document 231
# Word: pdci, TF-IDF: 0.16838
# Word: split, TF-IDF: 0.1491
# Word: recently, TF-IDF: 0.11305
# Top words in document 232
# Word: credit, TF-IDF: 0.17458
# Word: tiamo, TF-IDF: 0.13521
# Word: looksmart, TF-IDF: 0.13521
# Top words in document 233
# Word: maxcyber, TF-IDF: 0.12169
# Word: grande, TF-IDF: 0.12169
# Word: share, TF-IDF: 0.10321
# Top words in document 234
# Word: driver, TF-IDF: 0.22261
# Word: license, TF-IDF: 0.17819
# Word: suspend, TF-IDF: 0.11759
# Top words in document 235
# Word: prospectus, TF-IDF: 0.24338
# Word: offer, TF-IDF: 0.113
# Word: obtain, TF-IDF: 0.08721
# Top words in document 236
# Word: vacation, TF-IDF: 0.15515
# Word: package, TF-IDF: 0.12716
# Word: blackkey, TF-IDF: 0.11589
# Top words in document 237
# Word: win, TF-IDF: 0.04819
# Word: weekend, TF-IDF: 0.04085
# Word: capitalfm, TF-IDF: 0.03906
# Top words in document 238
# Word: wizard, TF-IDF: 0.08664
# Word: engine, TF-IDF: 0.07064
# Word: exposure, TF-IDF: 0.04053
# Top words in document 239
# Word: report, TF-IDF: 0.12697
# Word: marketplace, TF-IDF: 0.07375
# Word: updated, TF-IDF: 0.07375
# Top words in document 240
# Word: pic73, TF-IDF: 0.18368
# Word: ak2, TF-IDF: 0.16838
# Word: 856777947, TF-IDF: 0.1491
# Top words in document 241
# Word: scitechint, TF-IDF: 0.07893
# Word: product, TF-IDF: 0.0609
# Word: 9191, TF-IDF: 0.05262
# Top words in document 242
# Word: get-a, TF-IDF: 0.09184
# Word: envst100, TF-IDF: 0.09184
# Word: tmedia1, TF-IDF: 0.09184
# Top words in document 243
# Word: biggest, TF-IDF: 0.04826
# Word: millennium, TF-IDF: 0.04568
# Word: lucky, TF-IDF: 0.04357
# Top words in document 244
# Word: plurabelle, TF-IDF: 0.35791
# Word: book, TF-IDF: 0.11312
# Word: catalogue, TF-IDF: 0.11085
# Top words in document 245
# Word: money, TF-IDF: 0.04709
# Word: internet, TF-IDF: 0.04002
# Word: traffic, TF-IDF: 0.03837
# Top words in document 246
# Word: jokes4u, TF-IDF: 0.23827
# Word: confirmation, TF-IDF: 0.19342
# Word: ezine, TF-IDF: 0.06808
# Top words in document 247
# Word: vip, TF-IDF: 0.10297
# Word: motherboard, TF-IDF: 0.10297
# Word: retail, TF-IDF: 0.08698
# Top words in document 248
# Word: listbot, TF-IDF: 0.18055
# Word: bancurus, TF-IDF: 0.11254
# Word: vreus, TF-IDF: 0.08441
# Top words in document 249
# Word: web22b5f, TF-IDF: 0.21163
# Word: 814493884, TF-IDF: 0.194
# Word: package, TF-IDF: 0.1161
# Top words in document 250
# Word: beeb, TF-IDF: 0.04621
# Word: fierce, TF-IDF: 0.04236
# Word: mariah, TF-IDF: 0.04236
# Top words in document 251
# Word: webminer, TF-IDF: 0.37443
# Word: datum, TF-IDF: 0.36656
# Word: white, TF-IDF: 0.27806
# Top words in document 252
# Word: angels, TF-IDF: 0.17384
# Word: secrets, TF-IDF: 0.13038
# Word: putting, TF-IDF: 0.13038
# Top words in document 253
# Word: vacation, TF-IDF: 0.13298
# Word: florida, TF-IDF: 0.12554
# Word: 796264397, TF-IDF: 0.09934
# Top words in document 254
# Word: review, TF-IDF: 0.04204
# Word: inet, TF-IDF: 0.03941
# Word: magazine, TF-IDF: 0.03941
# Top words in document 255
# Word: ambra, TF-IDF: 0.19867
# Word: venture, TF-IDF: 0.11988
# Word: abrg, TF-IDF: 0.04967
# Top words in document 256
# Word: vacation, TF-IDF: 0.13032
# Word: florida, TF-IDF: 0.12303
# Word: 278549, TF-IDF: 0.09735
# Top words in document 257
# Word: latest, TF-IDF: 0.04575
# Word: capitalfm, TF-IDF: 0.04339
# Word: boyzone, TF-IDF: 0.03592
# Top words in document 258
# Word: 600, TF-IDF: 0.07096
# Word: trouble, TF-IDF: 0.06052
# Word: site, TF-IDF: 0.05892
# Top words in document 259
# Word: 600, TF-IDF: 0.07096
# Word: trouble, TF-IDF: 0.06052
# Word: site, TF-IDF: 0.05892
# Top words in document 260
# Word: tvsr, TF-IDF: 0.13512
# Word: quot, TF-IDF: 0.04173
# Word: tv, TF-IDF: 0.03097
